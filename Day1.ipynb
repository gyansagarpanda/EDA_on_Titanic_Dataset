# %% [markdown]
# <a href="https://colab.research.google.com/github/gyansagarpanda/EDA_on_Titanic_Dataset/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# **Why EDA**
# 1. Model Building
# 2. Analysis and Repotring
# 3. Validate Assumptions
# 4. Handling Missing Values
# 5. Feature Engineering
# 6. Detecting Outliers

# %% [markdown]
# Column Types
#
# Neumeric - Age, Fare, PassangerId
#
# Categorical -  Survived, Pclass, Sex, SibSp, Parch, Embarked
#
# Mixed - Name, Cabin , Ticket

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age'].plot(kind= 'hist', bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Age'].plot(kind= 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %%
df['Age'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df[df['Age'] >65]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 33            34         0       2                 Wheadon, Mr. Edward H
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# ...

# %%
(df['Age'].isnull().sum()/len(df['Age']))*100
# Out:
# 19.865319865319865

# %% [markdown]
# ### Age ###
# -Age is almost normally distributed
# -20% values are missing
# -There are some outliars present

# %%
df['Fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df['Fare'].plot(kind = 'hist', bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Fare'].plot(kind = 'kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Fare'].skew()
# Out:
# 4.787316519674893

# %%
df['Fare'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df[df['Fare']>250]
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 258          259         1       1                       Ward, Miss. Anna
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 27     male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# ...

# %%
df['Fare'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Fare
#
# -The data is positively skewed
#
# -Fare columns contains the group fare not individual fare
#
# -We need to create a new column for indivisual fare

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df['Survived'].value_counts().plot(kind = 'barh')
# Out:
# <Axes: >

# %%
df['Survived'].value_counts().plot(kind = 'pie', autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='Survived'>

# %% [markdown]
# Survived

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Pclass'].value_counts().plot(kind = 'barh')
# Out:
# <Axes: >

# %% [markdown]
# Pclass
# Surprisingly more people are in P class and less number of people are in P Class 2

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df['Sex'].value_counts().plot(kind = 'barh')
# Out:
# <Axes: >

# %%
df['Sex'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Sex
# looksfine

# %%
df['SibSp'].value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df['SibSp'].value_counts().plot(kind = 'pie' , autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='SibSp'>

# %%
df['SibSp'].isnull().sum()
# Out:
# 0

# %% [markdown]
# SibSp
#
# looks fine

# %%
df['Parch'].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
df['Parch'].value_counts().plot(kind = 'pie' , autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='Parch'>

# %%
df['Parch'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Parch
#
# -Parch & SibSp can be merged Called Family
#
# -Create a new column called is_alone

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df['Embarked'].value_counts().plot(kind = 'barh')
# Out:
# <Axes: >

# %% [markdown]
# Embarked
#
# -Looks fine

# %% [markdown]
# Mixed Columns
#
# -Need to feature engineer the mixed columns to get insights

# %% [markdown]
# g
